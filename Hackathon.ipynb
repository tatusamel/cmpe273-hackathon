# %%
# !pip install byaldi accelerate qwen_vl_utils pdf2image
# !sudo apt-get install -y poppler-utils
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.9/517.9 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 108.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 65.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 28.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 38.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 25.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.4/287.4 kB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 102.3 MB/s eta 0:00:00
# ...

# %%
from byaldi import RAGMultiModalModel
from qwen_vl_utils import process_vision_info
import torch
from pdf2image import convert_from_path

# %%
rag_engine = RAGMultiModalModel.from_pretrained("vidore/colpali")
# Out:
# Verbosity is set to 1 (active). Pass verbose=0 to make quieter.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
rag_engine.index(
    input_path="/content/Concatenated.pdf",
    index_name="/content/index",
    store_collection_with_index=False,
    overwrite=True
)
# Out:
# Added page 1 of document 0 to index.
# Added page 2 of document 0 to index.
# Added page 3 of document 0 to index.
# Added page 4 of document 0 to index.
# Added page 5 of document 0 to index.
# Added page 6 of document 0 to index.
# Added page 7 of document 0 to index.
# Added page 8 of document 0 to index.
# Added page 9 of document 0 to index.
# Added page 10 of document 0 to index.
# Added page 11 of document 0 to index.
# Added page 12 of document 0 to index.
# Added page 13 of document 0 to index.
# Added page 14 of document 0 to index.
# Added page 15 of document 0 to index.
# Added page 16 of document 0 to index.
# Added page 17 of document 0 to index.
# Added page 18 of document 0 to index.
# Added page 19 of document 0 to index.
# Added page 20 of document 0 to index.
# Added page 21 of document 0 to index.
# Added page 22 of document 0 to index.
# Added page 23 of document 0 to index.
# Added page 24 of document 0 to index.
# Added page 25 of document 0 to index.
# ...

# %%
# !zip -r /content/index.zip /content/index
# Out:
#   adding: content/index/ (stored 0%)
#   adding: content/index/embeddings/ (stored 0%)
#   adding: content/index/embeddings/embeddings_0.pt (deflated 21%)
#   adding: content/index/embeddings/embeddings_500.pt (deflated 21%)
#   adding: content/index/metadata.json.gz (stored 0%)
#   adding: content/index/doc_ids_to_file_names.json.gz (stored 0%)
#   adding: content/index/embed_id_to_doc_id.json.gz (deflated 48%)
#   adding: content/index/index_config.json.gz (stored 0%)

# %%
rag_engine = RAGMultiModalModel.from_index("/content/index")

# %%
text_query = "Explain increase prices impact on food security"

# %%
results = rag_engine.search(text_query, k = 5)

# %%
results
# Out:
# [{'doc_id': 0, 'page_num': 42, 'score': 13.5, 'metadata': {}, 'base64': '...'},
#  {'doc_id': 0, 'page_num': 43, 'score': 13.4375, 'metadata': {}, 'base64': '...'},
#  {'doc_id': 0, 'page_num': 45, 'score': 13.4375, 'metadata': {}, 'base64': '...'},
#  {'doc_id': 0, 'page_num': 316, 'score': 13.1875, 'metadata': {}, 'base64': '...'},
#  {'doc_id': 0, 'page_num': 58, 'score': 13.1875, 'metadata': {}, 'base64': '...'}]
